# %%
api_key = "RGAPI-88c342f6-74ca-4d3c-b85f-e39437b8aed3"
api_key
# Out:
# 'RGAPI-88c342f6-74ca-4d3c-b85f-e39437b8aed3'

# %%
api_url = "https://ph2.api.riotgames.com/lol/summoner/v4/summoners/by-puuid/qGeloSe4U5pVnGOLFeLeV7OuwETe3-00mg7v3F6cmM2pWNnl504gkN8IigSdGdTIZQokao3FurDUMA"

# %% [markdown]
# We will manage all of our API calls using the "requests" library.

# %%
import requests

# %%
requests.get(api_url)
# Out:
# <Response [401]>

# %%
api_url = api_url + '?api_key=' + api_key
api_url
# Out:
# 'https://ph2.api.riotgames.com/lol/summoner/v4/summoners/by-puuid/qGeloSe4U5pVnGOLFeLeV7OuwETe3-00mg7v3F6cmM2pWNnl504gkN8IigSdGdTIZQokao3FurDUMA?api_key=RGAPI-88c342f6-74ca-4d3c-b85f-e39437b8aed3'

# %%
requests.get(api_url)
# Out:
# <Response [200]>

# %%
resp = requests.get(api_url)
player_info = resp.json()
player_info
# Out:
# {'id': 'kGvHEkr9xyhKlPYzlAPXNOBBUQ5WuefF-MYCgSSRRd24UQvtlJCyTKIm3g',
#  'accountId': 'rXWpKHBLfV1PK2zA7ryoDlyTD-rIZp793iCgkg9P9TscPcE8cDwBnnt7',
#  'puuid': 'qGeloSe4U5pVnGOLFeLeV7OuwETe3-00mg7v3F6cmM2pWNnl504gkN8IigSdGdTIZQokao3FurDUMA',
#  'profileIconId': 3232,
#  'revisionDate': 1727704532858,
#  'summonerLevel': 549}

# %%
puuid = player_info['puuid']
puuid
# Out:
# 'qGeloSe4U5pVnGOLFeLeV7OuwETe3-00mg7v3F6cmM2pWNnl504gkN8IigSdGdTIZQokao3FurDUMA'

# %%
api_url = "https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/qGeloSe4U5pVnGOLFeLeV7OuwETe3-00mg7v3F6cmM2pWNnl504gkN8IigSdGdTIZQokao3FurDUMA/ids?queue=420&start=0&count=20"

# %%
api_url = api_url + "&api_key=" + api_key
api_url
# Out:
# 'https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/qGeloSe4U5pVnGOLFeLeV7OuwETe3-00mg7v3F6cmM2pWNnl504gkN8IigSdGdTIZQokao3FurDUMA/ids?queue=420&start=0&count=20&api_key=RGAPI-88c342f6-74ca-4d3c-b85f-e39437b8aed3'

# %% [markdown]
# This API contains a list of the match IDs from my account's last 20 games

# %%
resp = requests.get(api_url)
match_ids = resp.json()

match_ids
# Out:
# ['PH2_67612582',
#  'PH2_67605866',
#  'PH2_67543129',
#  'PH2_67536808',
#  'PH2_67508018',
#  'PH2_67498574',
#  'PH2_67408415',
#  'PH2_67356694',
#  'PH2_67351737',
#  'PH2_67274253',
#  'PH2_67265799',
#  'PH2_67014530',
#  'PH2_66821334',
#  'PH2_66819205',
#  'PH2_66814212',
#  'PH2_66713715',
#  'PH2_66708601',
#  'PH2_66705306',
#  'PH2_66702228',
#  'PH2_66611966']

# %%
recent_match = match_ids[0]

recent_match
# Out:
# 'PH2_67612582'

# %%
api_url = "https://sea.api.riotgames.com/lol/match/v5/matches/PH2_67014530"

# %%
api_url = api_url + "?api_key=" + api_key

# %%
resp = requests.get(api_url)
match_data = resp.json()

match_data
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'PH2_67014530',
#   'participants': ['T8q-4God8MixJy1DDdMBERHg2ZjdwqO2hyNrIzBOADAnzpp1Nat78WbN6r37Gj6flgp-c2pB5BArBw',
#    'v8MJh6TzOiylB85FYTURIb73rL7qjGVwYYkwcAStqBG94gnsJSHWnbVy_ZLk3ujBdVU5Yhx4M_Dnwg',
#    'Z-KczwoJ90D4e5REE_fkMYVGXwZn8GJUVq5WXRxJYbJcGBPRb7aTzCO809TvbRkIhbb3cMKHFYc11A',
#    '5986ChDAO62KB3G-p88XFTk9Kv7yor59yApKEhYIpj2wEQJQOc2mPCs847hIUfdTsHCl6ypYLsslrA',
#    '5_FigQF5S3zoom5ewYy8y9E9N4s9vMd1LPjCxJ-PsWw96mv7Vnu92jSOdMuBjhewRlHc4Kw0pRR9Kw',
#    'ohWdRP4HlIV8VnHMtomFdW_ARpCMx0tN1F_o-ECTDAVUe0VAoId1qsue28emC8XZLe7WOKAniRE1sw',
#    'L95Y-R3xYbkW0GYdUbinYaIK7IFLvBDvOuHPw5dC3Dt9rw0Q47NZlOw5BhTYOIuivKRZ5IPpVnT04w',
#    '1OZf_smF1kKDcEVJ0lfsXsfLtrQjZ7KQK8DWIc1_ak4VYdNBo7YW1TeO8vZlldnWxkXMWtUrIN1uPg',
#    'qGeloSe4U5pVnGOLFeLeV7OuwETe3-00mg7v3F6cmM2pWNnl504gkN8IigSdGdTIZQokao3FurDUMA',
#    'ee57FqzpTTj_mcQ6bRDnxU93wAPg7tvvF06lRCwxRG_wyNEMehoMUPrtlmr3VuZCO9nBljCRhkSB7Q']},
# ...

# %% [markdown]
# Let's break this data into smaller parts.

# %%
match_data.keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
match_data['metadata']
# Out:
# {'dataVersion': '2',
#  'matchId': 'PH2_67014530',
#  'participants': ['T8q-4God8MixJy1DDdMBERHg2ZjdwqO2hyNrIzBOADAnzpp1Nat78WbN6r37Gj6flgp-c2pB5BArBw',
#   'v8MJh6TzOiylB85FYTURIb73rL7qjGVwYYkwcAStqBG94gnsJSHWnbVy_ZLk3ujBdVU5Yhx4M_Dnwg',
#   'Z-KczwoJ90D4e5REE_fkMYVGXwZn8GJUVq5WXRxJYbJcGBPRb7aTzCO809TvbRkIhbb3cMKHFYc11A',
#   '5986ChDAO62KB3G-p88XFTk9Kv7yor59yApKEhYIpj2wEQJQOc2mPCs847hIUfdTsHCl6ypYLsslrA',
#   '5_FigQF5S3zoom5ewYy8y9E9N4s9vMd1LPjCxJ-PsWw96mv7Vnu92jSOdMuBjhewRlHc4Kw0pRR9Kw',
#   'ohWdRP4HlIV8VnHMtomFdW_ARpCMx0tN1F_o-ECTDAVUe0VAoId1qsue28emC8XZLe7WOKAniRE1sw',
#   'L95Y-R3xYbkW0GYdUbinYaIK7IFLvBDvOuHPw5dC3Dt9rw0Q47NZlOw5BhTYOIuivKRZ5IPpVnT04w',
#   '1OZf_smF1kKDcEVJ0lfsXsfLtrQjZ7KQK8DWIc1_ak4VYdNBo7YW1TeO8vZlldnWxkXMWtUrIN1uPg',
#   'qGeloSe4U5pVnGOLFeLeV7OuwETe3-00mg7v3F6cmM2pWNnl504gkN8IigSdGdTIZQokao3FurDUMA',
#   'ee57FqzpTTj_mcQ6bRDnxU93wAPg7tvvF06lRCwxRG_wyNEMehoMUPrtlmr3VuZCO9nBljCRhkSB7Q']}

# %%
match_data['info'].keys()
# Out:
# dict_keys(['endOfGameResult', 'gameCreation', 'gameDuration', 'gameEndTimestamp', 'gameId', 'gameMode', 'gameName', 'gameStartTimestamp', 'gameType', 'gameVersion', 'mapId', 'participants', 'platformId', 'queueId', 'teams', 'tournamentCode'])

# %%
match_data['info']['gameDuration'] / 60  # We divide this by 60 to get it into minutes.
# Out:
# 28.316666666666666

# %%
len(match_data['info']['participants'])
# Out:
# 10

# %% [markdown]
# I tried to look for my account  in the match and I successfully found it.

# %%
player_data = match_data['info']['participants'][8]
player_data
# Out:
# {'allInPings': 0,
#  'assistMePings': 1,
#  'assists': 8,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 2,
#  'challenges': {'12AssistStreakCount': 0,
#   'InfernalScalePickup': 0,
#   'SWARM_DefeatAatrox': 0,
#   'SWARM_DefeatBriar': 0,
#   'SWARM_DefeatMiniBosses': 0,
#   'SWARM_EvolveWeapon': 0,
#   'SWARM_Have3Passives': 0,
#   'SWARM_KillEnemy': 0,
#   'SWARM_PickupGold': 0,
#   'SWARM_ReachLevel50': 0,
#   'SWARM_Survive15Min': 0,
#   'SWARM_WinWith5EvolvedWeapons': 0,
#   'abilityUses': 155,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 0,
#   'baronBuffGoldAdvantageOverThreshold': 1,
#   'baronTakedowns': 1,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 375,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7687831657480895,
#   'controlWardsPlaced': 2,
#   'damagePerMinute': 616.6278771878535,
#   'damageTakenOnTeamPercentage': 0.12771421863189217,
# ...

# %%
player_data['championName']
# Out:
# 'Xayah'

# %%
k = player_data['kills']
d = player_data['deaths']
a = player_data['assists']

print("kills: ", k)
print("deaths: ", d)
print("assists: ", a)
print("KDA: ", (k + a) / d )
# Out:
# kills:  7
# deaths:  4
# assists:  8
# KDA:  3.75

# %%
player_data['teamPosition']
# Out:
# 'BOTTOM'

# %% [markdown]
# When we want to get the data about the player we were searching for, we need to find out where they are. We can grab the list of all the participants puuios and then we use "index" to search.

# %%
participants = match_data['metadata']['participants']

player_index = participants.index(puuid)
player_index
# Out:
# 8

# %%
participants[player_index]
# Out:
# 'qGeloSe4U5pVnGOLFeLeV7OuwETe3-00mg7v3F6cmM2pWNnl504gkN8IigSdGdTIZQokao3FurDUMA'

# %% [markdown]
# Let's use this method to get the player's name from the data.

# %%
match_data['info']['participants'][player_index]['summonerName']
# Out:
# 'Rushia Pettanko'

# %% [markdown]
# Now that we know where my account is, we can access the data.

# %%
player_data = match_data['info']['participants'][player_index]

champ = player_data['championName']
k = player_data['kills']
d = player_data['deaths']
a = player_data['assists']
win = player_data['win']

print(f"Champ: {champ}\nKills: {k}\nDeaths: {d}\nAssists: {a}\nWin: {win}")
# Out:
# Champ: Xayah
# Kills: 7
# Deaths: 4
# Assists: 8
# Win: True

# %% [markdown]
# If we will collect a lot of data from a player, we need to create some functions to make our lives easier.

# %%
def  get_puuid(summonerId, region, api_key):
    api_url = (
        "https://" +
        region +
        ".api.riotgames.com/lol/summoner/v4/summoners/" +
        summonerId +
        "?api_key=" +
        api_key
    )


    print(api_url)

    resp = requests.get(api_url)
    player_info = resp.json()
    puuid = player_info['puuid']
    return puuid

# %%
summonerId = 'kGvHEkr9xyhKlPYzlAPXNOBBUQ5WuefF-MYCgSSRRd24UQvtlJCyTKIm3g'
region = "ph2"

puuid = get_puuid(summonerId, region, api_key)
puuid
# Out:
# https://ph2.api.riotgames.com/lol/summoner/v4/summoners/kGvHEkr9xyhKlPYzlAPXNOBBUQ5WuefF-MYCgSSRRd24UQvtlJCyTKIm3g?api_key=RGAPI-88c342f6-74ca-4d3c-b85f-e39437b8aed3
# 'qGeloSe4U5pVnGOLFeLeV7OuwETe3-00mg7v3F6cmM2pWNnl504gkN8IigSdGdTIZQokao3FurDUMA'

# %%
def get_match_ids(puuid, mass_region, api_key):
    api_url = (
        "https://" +
        mass_region +
        ".api.riotgames.com/lol/match/v5/matches/by-puuid/" +
        puuid + 
        "/ids?start=0&count=20" + 
        "&api_key=" + 
        api_key
    )
    
    print(api_url)
    
    resp = requests.get(api_url)
    match_ids = resp.json()
    return match_ids

# %%
mass_region = "sea"

match_ids = get_match_ids(puuid, mass_region, api_key)
match_ids
# Out:
# https://sea.api.riotgames.com/lol/match/v5/matches/by-puuid/qGeloSe4U5pVnGOLFeLeV7OuwETe3-00mg7v3F6cmM2pWNnl504gkN8IigSdGdTIZQokao3FurDUMA/ids?start=0&count=20&api_key=RGAPI-88c342f6-74ca-4d3c-b85f-e39437b8aed3
# ['PH2_67612582',
#  'PH2_67605866',
#  'PH2_67543129',
#  'PH2_67536808',
#  'PH2_67508018',
#  'PH2_67498574',
#  'PH2_67408415',
#  'PH2_67356694',
#  'PH2_67351737',
#  'PH2_67274253',
#  'PH2_67265799',
#  'PH2_67130682',
#  'PH2_67131314',
#  'PH2_67124892',
#  'PH2_67014530',
#  'PH2_66821334',
#  'PH2_66819205',
#  'PH2_66814212',
#  'PH2_66713715',
#  'PH2_66708601']

# %%
def get_match_data(match_id, mass_region, api_key):
    api_url = (
        "https://" + 
        mass_region + 
        ".api.riotgames.com/lol/match/v5/matches/" +
        match_id + 
        "?api_key=" + 
        api_key
    )
    
    resp = requests.get(api_url)
    match_data = resp.json()
    return match_data

# %%
match_id = match_ids[0]
match_data = get_match_data(match_id, mass_region, api_key)
match_data
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'PH2_67612582',
#   'participants': ['MDQwdrkHN9S4g9rJF3ZNKidtYogR48mJPh6C-0EljNuErcHWFdY5TGJ7aD2baw4sl0drvBke9R-BFw',
#    '-31Wj2r0WfG-IaFIeRhI-zVoaCC_jCvos3iWYCmnKMXsAL941iEsGM-8zkBDZsSCLmv-V82AgCeHgA',
#    'SK2_T-Ludb4rdMa_ktc9xH4ej00U7zGQSLsVk0s07okZ_QmbHvC-6rpnxdchuDOEzaQ6W-pviVAqfw',
#    'tThuXzdk2pu-TcmITCANSW2BH5gEiS1nu_-iqWa-OH0VYWqW6M9q0LijogxJsDtipu03_AODbJNlag',
#    'VtERH8wvYtLxkNieZV2Y_xoYyfOWhHC6PF4WbGTSumHKbrmhIwdXGFuHDws7FPo_4MaSF8oiIfPUfQ',
#    'fqwjnhjQsRx6G-5HjtXkGro_s2m6J7VZnbWUi6iX0KsBcogLmTQvp5t0VDqYnSJq_N2CKxn2h5OS5A',
#    'nIVT6j2RiXs457RdWAbrQ3lX_yVH8-oEEpUnjQJPLXkDuCU7iFQPVmFNfpLfrZYmZhqv3N-43IhZmg',
#    'r31-PsQbHhe0JThZtCu-7kJ2Kaeq4bMNytmoVb9CWOpW4jmEv3tI8tGIRK6XSU0JF4F07HaR0CsToA',
#    'qGeloSe4U5pVnGOLFeLeV7OuwETe3-00mg7v3F6cmM2pWNnl504gkN8IigSdGdTIZQokao3FurDUMA',
#    'z9IjAmCVDC72n9Z2A_7mrI6x3_SrTU0z_xe8d_d7LptR3S7QMFy8cn7Ie0YnMSZpBkSiW_uPsOirDA']},
# ...

# %%
def find_player_data(match_data, puuid):
    participants = match_data['metadata']['participants']
    player_index = participants.index(puuid)
    player_data = match_data['info']['participants'][player_index]
    return player_data

# %%
find_player_data(match_data, puuid)
# Out:
# {'allInPings': 0,
#  'assistMePings': 1,
#  'assists': 13,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 2,
#  'challenges': {'12AssistStreakCount': 0,
#   'HealFromMapSources': 0,
#   'InfernalScalePickup': 0,
#   'SWARM_DefeatAatrox': 0,
#   'SWARM_DefeatBriar': 0,
#   'SWARM_DefeatMiniBosses': 0,
#   'SWARM_EvolveWeapon': 0,
#   'SWARM_Have3Passives': 0,
#   'SWARM_KillEnemy': 0,
#   'SWARM_PickupGold': 0,
#   'SWARM_ReachLevel50': 0,
#   'SWARM_Survive15Min': 0,
#   'SWARM_WinWith5EvolvedWeapons': 0,
#   'abilityUses': 170,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 3,
#   'baronBuffGoldAdvantageOverThreshold': 1,
#   'baronTakedowns': 1,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 0,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardTimeCoverageInRiverOrEnemyHalf': 0.5678093658853945,
#   'controlWardsPlaced': 4,
#   'damagePerMinute': 979.0212594707637,
# ...
